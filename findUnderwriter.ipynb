# %%
import pandas as pd
import requests
from IPython.display import display

# %%
def get_underwriter():
    url = "https://www.iposcoop.com/ipo-calendar/"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    response = requests.get(url, headers=headers)
    df = pd.read_html((response.text))
    if df:
        ipo_df = df[0]
        if 'Lead Managers' in ipo_df.columns:
            return ipo_df#[['Company', 'Lead Managers', 'Symbol proposed']]
    
    return None

# %%
ddf = get_underwriter()
if ddf is not None:
    print(ddf)
else:
    print("No IPO Data Found")
# Out:
#                                           Company Symbol proposed  \
# 0   Bitcoin Infrastructure Acquisition Corp. Ltd.           BIXIU
# 1               General Purpose Acquisition Corp.           GPACU
# 2                               SilverBox Corp. V          SBXE.U
# 3                 New America Acquisition I Corp.           NWAXU
# 4                     Regentis Biomaterials, Ltd.            RGNT
# 5                                   DT House Ltd.            DTDT
# 6        HW Electro Co., Ltd. (NASDAQ-New Filing)            HWEP
# 7                               Wealthfront Corp.            WLTH
# 8                         Cardinal Infrastructure            CDNL
# 9                         Lumexa Imaging Holdings            LMRI
# 10                              AIGO Holding Ltd.            AIGO
# 11                      ALE Group Holding Limited            ALEH
# 12                        ELC Group Holdings Ltd.            ELCG
# 13                    Monkey Tree Investment Ltd.            MKTR
# 14                                     PressLogic            PLAI
# 15                              Riku Dining Group            RIKU
# 16                                      Ultratrex             UTX
#
#                                         Lead Managers  Shares (Millions)  \
# 0                     Cohen & Company Capital Markets               20.0
# 1                                           Jefferies               20.0
# 2                                           Santander               24.0
# 3   Dominari Securities/D. Boral Capital (ex-EF Hu...               30.0
# 4                                         ThinkEquity                1.0
# 5                  American Trust Investment Services                2.0
# 6   American Trust Investment Services/WestPark Ca...                4.2
# 7   Goldman Sachs/J.P. Morgan/Citigroup/Wells Farg...               34.6
# 8           Stifel/William Blair/ D.A. Davidson & Co.               11.5
# 9   Barclays/J.P.Morgan/Jefferies/Deutsche Bank Se...               25.0
# 10                               Eddid Securities USA                2.0
# 11                    D. Boral Capital (ex-EF Hutton)                1.5
# 12                    D. Boral Capital (ex-EF Hutton)                1.9
# 13         Craft Capital Management/Revere Securities                1.6
# 14                 American Trust Investment Services                1.8
# 15                               Eddid Securities USA                2.3
# 16                           Craft Capital Management                1.3
#
#     Price Low  Price High Est. $ Volume     Expected to Trade SCOOP Rating  \
# 0        10.0        10.0   $ 200.0 mil      12/2/2025 Priced          S/O
# 1        10.0        10.0   $ 200.0 mil      12/3/2025 Priced          S/O
# 2        10.0        10.0   $ 240.0 mil      12/3/2025 Priced          S/O
# 3        10.0        10.0   $ 300.0 mil    12/4/2025 Thursday          S/O
# 4        10.0        12.0    $ 11.0 mil    12/4/2025 Thursday          S/O
# 5         4.0         5.0     $ 9.0 mil     12/5/2025 Week of          S/O
# 6         4.0         4.0    $ 16.6 mil     12/8/2025 Week of          S/O
# 7        12.0        14.0   $ 450.0 mil     12/8/2025 Week of          S/O
# 8        20.0        22.0   $ 241.5 mil  12/10/2025 Wednesday          S/O
# 9        17.0        20.0   $ 462.5 mil   12/11/2025 Thursday          S/O
# 10        4.0         6.0    $ 10.0 mil    12/15/2025 Week of          S/O
# 11        4.0         6.0     $ 7.5 mil    12/15/2025 Week of          S/O
# 12        4.0         6.0     $ 9.4 mil    12/15/2025 Week of          S/O
# 13        4.0         5.0     $ 7.0 mil    12/15/2025 Week of          S/O
# 14        4.0         6.0     $ 9.0 mil    12/15/2025 Week of          S/O
# 15        4.0         6.0    $ 11.3 mil    12/15/2025 Week of          S/O
# 16        4.0         6.0     $ 6.3 mil    12/15/2025 Week of          S/O
#
#    Rating Change
# 0            S/O
# 1            S/O
# 2            S/O
# 3            S/O
# 4            S/O
# 5            S/O
# 6            S/O
# 7            S/O
# 8            S/O
# 9            S/O
# 10           S/O
# 11           S/O
# 12           S/O
# 13           S/O
# 14           S/O
# 15           S/O
# 16           S/O
# /var/folders/zc/8mxyhmj11_d5jjcgbxm1s4jr0000gn/T/ipykernel_79455/2193734637.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html((response.text))
